# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Match with event topics

# %%
transcript_meta = pd.read_csv("youtube_video_metadata.csv",encoding = "utf-8")
transcript_meta
# Out:
#      video_num                                       link  \
# 0            0  https://youtube.com/watch?v=J5oVwdqf3kw\n
# 1            1  https://youtube.com/watch?v=uNiGFQcDMhg\n
# 2            2  https://youtube.com/watch?v=_MSNS2pA_mU\n
# 3            3  https://youtube.com/watch?v=cLMFlZT-rKo\n
# 4            4  https://youtube.com/watch?v=ZWP3MgowIxo\n
# ..         ...                                        ...
# 358        358  https://youtube.com/watch?v=PwvzT-sEU2I\n
# 359        359  https://youtube.com/watch?v=pf2jCUauvUg\n
# 360        360  https://youtube.com/watch?v=MxYmoeS1i_4\n
# 361        361  https://youtube.com/watch?v=SMKIn84snls\n
# 362        362  https://youtube.com/watch?v=4iVr7xIlM_o\n
#
#                                                  title publish_date  \
# 0    Faiths for a just transition: bottom up and sy...   2024-01-03
# 1    Article 6 on the ground - Real solutions inste...   2024-01-02
# ...

# %%
energy_events = pd.read_csv("../extracted_events_energy.csv",encoding = "utf-8")
energy_cop28 = energy_events[energy_events["COP"]=="COP28"]

for i in transcript_meta.index:
    title = transcript_meta.loc[i,"title"]
    check_title = energy_cop28[energy_cop28["Title/Description"].str.contains(title)]
    if len(check_title)==0:
        continue
    else:
        energy_cop28.loc[check_title.index,"video_num"] = transcript_meta.loc[i,"video_num"]
energy_cop28.loc[20,"video_num"] = 68 # manual check
energy_cop28.loc[17,"video_num"] = 129 # manual check
energy_cop28.to_csv("cop28_video_match_energy.csv")
# Out:
# C:\Users\jx920\AppData\Local\Temp\ipykernel_50044\1136218139.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_cop28.loc[check_title.index,"video_num"] = transcript_meta.loc[i,"video_num"]
# C:\Users\jx920\AppData\Local\Temp\ipykernel_50044\1136218139.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   check_title = energy_cop28[energy_cop28["Title/Description"].str.contains(title)]
# C:\Users\jx920\AppData\Local\Temp\ipykernel_50044\1136218139.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# ...

# %%
food_events = pd.read_csv("../extracted_events_food.csv",encoding = "utf-8")
food_cop28 = food_events[food_events["COP"]=="COP28"]
for i in transcript_meta.index:
    title = transcript_meta.loc[i,"title"]
    check_title = food_cop28[food_cop28["Title/Description"].str.contains(title)]
    if len(check_title)==0:
        continue
    else:
        food_cop28.loc[check_title.index,"video_num"] = transcript_meta.loc[i,"video_num"]
food_cop28.loc[24,"video_num"] = 36 # manual match
food_cop28.to_csv("cop28_video_match_food.csv")
# Out:
# C:\Users\jx920\AppData\Local\Temp\ipykernel_50044\1349602327.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   food_cop28.loc[check_title.index,"video_num"] = transcript_meta.loc[i,"video_num"]
# C:\Users\jx920\AppData\Local\Temp\ipykernel_50044\1349602327.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   check_title = food_cop28[food_cop28["Title/Description"].str.contains(title)]
# C:\Users\jx920\AppData\Local\Temp\ipykernel_50044\1349602327.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# ...
